# %%
import os
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "True"

# %%
p = Place.objects.all()

# %%
test = p.first()

# %%
place_labels = []
[place_labels.append(label) for obj in Place.objects.all() for label in obj.label_set.all()]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
len(place_labels)
# Out:
# 1399

# %%
cats = [l.label_type.name for l in place_labels]

# %%
cats = set(cats)

# %%
cats
# Out:
# {'Bezeichnung, Adresse 1822',
#  'Bezeichnung, Suttingerstadtplan',
#  'Bezeichnung, alternativ',
#  'Stadtviertel_1730',
#  'URI_p_lucienfeld_harrer',
#  'URI_wien_wiki'}

# %%
pcs = Place.objects.values_list("kind__name", flat=True)

# %%
for p in Place.objects.all(): 
    if not p.kind: 
        print(p)
# Out:
# Düsseldorf
# Valladolid
# Neustadt an der Waldnaab
# Campoverardo
# abwesend
# Rennweg 485 <Landstraße>
# Schultergasse 443
# Schultergasse 428

# %%
PersonPlace.objects.count()
# Out:
# 6907

# %%
PlacePlace.objects.count()
# Out:
# 2517

# %%
InstitutionPlace.objects.count()
# Out:
# 888

# %%
PlaceEvent.objects.count()
# Out:
# 13

# %%
PlaceWork.objects.count()
# Out:
# 282

# %%
for el in PlacePlaceRelation.objects.all(): 
    print(el.name)
# Out:
# liegt in
# liegt bei
# ist potentielle Doublette von
# liegt neben
# liegt vor
# liegt hinter
# liegt gegenüber von

# %%
for el in PersonPlaceRelation.objects.all(): 
    print(el.name)
# Out:
# studierte in
# ist gestorben in
# hat sich aufgehalten in
# ist geboren in
# residierte in
# war tätig bei/in
# wirkte in
# reiste nach
# wohnte in
# wohnte neben
# familiäre Abstammung aus
# stammte aus
# wohnhaft in
# wurde angelobt in
# wurde ernannt in
# Aufenthalts- & Tätigkeitsort
# Reiseort
# Herkunftsort
# Wohnort
# Zeremonieller Ort
# Sterbeort
# wohnte in eigenem Haus in
# wohnte in eigenem Haus in der Nähe von
# wohnte in eigenem Haus gegenüber
# wohnte in eigenem Haus neben
# wohnte in eigenem Haus bei
# wohnte bei
# wohnte in Hofquartier bei
# wohnte gegenüber von
# wohnte hinter
# wohnte in der Nähe von
